# %% [markdown]
# # ME-CCE: Lindblad Master Equation 튜토리얼
# ### CCEX `simulator_mecce.cpp` + `superoperator.cpp` Python 구현
#
# ---
#
# 이 노트북은 CCEX에 새로 추가된 **ME-CCE** 방법의 핵심 수학과 코드를 단계별로 설명합니다.
# C++ 코드와 **1:1 대응**되는 Python 함수를 직접 구현하고, 간단한 모델로 검증합니다.
#
# **모델:** 큐빗(S=1/2) + 배스 스핀 1개(S=1/2, 전자 스핀)
#
# **목차:**
# 1. [배경: Lindblad Master Equation](#1.-배경:-Lindblad-Master-Equation)
# 2. [Superoperator Formalism](#2.-Superoperator-Formalism)
# 3. [C++ → Python 구현](#3.-C++→Python-구현)
# 4. [간단한 모델 설정](#4.-간단한-모델-설정)
# 5. [검증: Ramsey — CCE = ME-CCE(rate=0)](#5.-검증:-Ramsey)
# 6. [물리: Hahn Echo + Lindblad 효과](#6.-Hahn-Echo-+-Lindblad-효과)
# 7. [요약: 새로운 방법들](#7.-요약:-CCEX-새로운-방법들)
